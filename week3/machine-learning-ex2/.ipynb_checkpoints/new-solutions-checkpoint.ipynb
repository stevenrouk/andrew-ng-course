# %% [markdown]
# # Week 3 Work: Logistic Regression & Regularization
#
# Welcome to Week 3!
#
# In this week, we start taking a look at a machine learning method for "classification", which is where we try to figure out how to predict labeled data, or data with discrete classes (as opposed to real-valued outputs).
#
# **First**, we're going to take a look at the logistic regression which is a method of classifying data, and the logistic regression *hypothesis function*.

# %%
# %matplotlib inline

import math
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os

# %%
data_path = os.path.join('ex2', 'ex2data1.txt')

with open(data_path, 'r') as f:
    data = np.array([[float(item) for item in row.split(',')] for row in f.read().strip().split('\n')])
X, y = data[:, :-1], data[:, -1].astype(int)

print(X.shape)
print(y.shape)
# Out:
# (100, 2)
# (100,)

# %%
df1 = pd.DataFrame(data, columns=['x1', 'x2', 'y'])
df1['y'] = df1['y'].astype('int')
sns.lmplot(x='x1', y='x2', hue='y', data=df1, fit_reg=False, markers=["o", "x"], palette="Set1")
plt.title('Data 1')

# %%
# Sigmoid / Logistic Function
def g(x):
    return 1 / (1 + np.e ** (-x))

# Logistic Regression Hypothesis Function
def h(X, theta):
    return g(X.dot(theta))

# Logistic Regression Cost Function
def cost(X, y, theta):
    return (-1 / len(X)) * sum(y*np.log(h(X, theta)) + (1-y)*np.log(1-h(X, theta)))

def update_theta(X, y, theta, alpha):
    return theta - (alpha / len(X)) * X.T.dot(h(X, theta) - y)

# %%
X = np.concatenate((np.ones(X.shape[0])[:, None], X), axis=1)
theta = np.zeros(X.shape[1])
for x in range(1000000):
    theta = update_theta(X, y, theta, alpha=0.1)
    
print(theta)
# Out:
# [-557.82686435    4.82062407    4.74168239]

# %%
sns.lmplot(x='x1', y='x2', hue='y', data=df1, fit_reg=False, markers=["o", "x"], palette="Set1")
plt.title('Data 1')
lineplot = [(-theta[0]-theta[1]*x)/theta[2] for x in range(100)]
plt.plot(lineplot)

# %%
cost(X, y, theta)
# Out:
# nan

# %%
class Normalizer:

    def __init__(self):
        self.X = None
        self.X_transformed = None
        self.X_mean = None
        self.X_stdev = None

    def fit(self, X):
        self.X = X
        self.X_mean = self.X.mean(axis=0)
        self.X_mean[0] = 0
        self.X_stdev = self.X.std(axis=0)
        self.X_stdev[0] = 1
        self.X_transformed = (self.X - self.X_mean) / self.X_stdev

    def fit_transform(self, X):
        self.fit(X)
        return self.X_transformed

    def get_transformed(self):
        return self.X_transformed
    
    def transform(self, X):
        return (X - self.X_mean) / self.X_stdev
    
    def unfit_theta(self, theta):
        """
        Converts the parameters from the normalized space back to the original space.
        
        Input: list theta
        Output: list
        
        This equation can be verified by looking at a normalized example [1, (x1 - x1_mean)/x1_std, (x2 - x2_mean)/x2_std, ...],
        multiplying this example by parameters [theta_0, theta_1, theta_2, ...] to get prediction y,
        and then rearranging terms to leave the individual x terms not normalized and all the constants grouped
        under a new theta_0.
        """
        theta_0 = theta[0] - sum(theta[1:]*self.X_mean[1:]/self.X_stdev[1:])
        theta_rest = theta[1:]/self.X_stdev[1:]
        return [theta_0, *theta_rest]

# %%
nm = Normalizer()
X_norm = nm.fit_transform(X)

theta_norm = np.zeros(X_norm.shape[1])
for x in range(1000000):
    theta_norm = update_theta(X_norm, y, theta_norm, alpha=0.1)
    
print(theta_norm)

print(cost(X_norm, y, theta_norm))
# Out:
# [ 1.71844948  3.99278759  3.72513649]
# 0.203497701589

# %%
data_norm = np.concatenate((X_norm[:, 1:], y[:, None]), axis=1)
df_norm = pd.DataFrame(data_norm, columns=['x1', 'x2', 'y'])
df_norm['y'] = df_norm['y'].astype('int')

sns.lmplot(x='x1', y='x2', hue='y', data=df_norm, fit_reg=False, markers=["o", "x"], palette="Set1")
plt.title('Data Norm')
lineplot = [(-theta_norm[0]-theta_norm[1]*x)/theta_norm[2] for x in range(-2,2)]
plt.plot(range(-2,2), lineplot)

# %% [markdown]
# ## Part Two: Non-Linearly-Separable Data

# %%
data_path2 = os.path.join('ex2', 'ex2data2.txt')

with open(data_path2, 'r') as f:
    data2 = np.array([[float(item) for item in row.split(',')] for row in f.read().strip().split('\n')])
X2, y2 = data2[:, :-1], data2[:, -1].astype(int)

print(X2.shape, y2.shape)
# Out:
# (118, 2) (118,)

# %%
df2 = pd.DataFrame(data2, columns=['x1', 'x2', 'y'])
df2['y'] = df2['y'].astype('int')
sns.lmplot(x='x1', y='x2', hue='y', data=df2, fit_reg=False, markers=["o", "x"], palette="Set1")
plt.title('Data 2')

# %%
X2 = np.concatenate((np.ones(X2.shape[0])[:, None], X2), axis=1)
theta2 = np.zeros(X2.shape[1])
for x in range(1000000):
    theta2 = update_theta(X2, y2, theta2, alpha=0.1)
    
print(theta2)

print(cost(X2, y2, theta2))
# Out:
# [-0.01418412 -0.30352113 -0.01813178]
# 0.690241122017

# %%
df2 = pd.DataFrame(data2, columns=['x1', 'x2', 'y'])
df2['y'] = df2['y'].astype('int')
sns.lmplot(x='x1', y='x2', hue='y', data=df2, fit_reg=False, markers=["o", "x"], palette="Set1")
plt.title('Data 2 Linear Fit')

lineplot = [(-theta2[0]-theta2[1]*x)/theta2[2] for x in np.arange(-1,1,0.1)]
plt.plot(np.arange(-1,1,0.1), lineplot)

# %%
X2_poly = np.concatenate((X2, (X2[:, 1]**2)[:, None], (X2[:, 2]**2)[:, None]), axis=1)
X2_poly[:2]
# Out:
# array([[ 1.        ,  0.051267  ,  0.69956   ,  0.00262831,  0.48938419],
#        [ 1.        , -0.092742  ,  0.68494   ,  0.00860108,  0.4691428 ]])

# %%
theta2_poly = np.zeros(X2_poly.shape[1])
for x in range(1000000):
    theta2_poly = update_theta(X2_poly, y2, theta2_poly, alpha=0.1)
    
print(theta2_poly)

print(cost(X2_poly, y2, theta2_poly))
# Out:
# [ 3.81164607  1.35847914  2.29942288 -8.45116442 -7.77858164]
# 0.434956560244

# %%
sns.lmplot(x='x1', y='x2', hue='y', data=df2, fit_reg=False, markers=["o", "x"], palette="Set1")
plt.title('Data 2 Quadratic Fit')

a = theta2_poly[4]
b = theta2_poly[2]
lineplottop = [(-b + (b**2 - 4*a*(theta2_poly[0] + theta2_poly[1]*x + theta2_poly[3]*x**2))**0.5) / (2*a) for x in np.arange(-1,1,0.01)]
lineplotbottom = [(-b - (b**2 - 4*a*(theta2_poly[0] + theta2_poly[1]*x + theta2_poly[3]*x**2))**0.5) / (2*a) for x in np.arange(-1,1,0.01)]

plt.plot(np.arange(-1,1,0.01), lineplottop, 'black')
plt.plot(np.arange(-1,1,0.01), lineplotbottom, 'black')

# %%
X2_superpoly = np.concatenate((
        X2,
        (X2[:, 1]**1 * X2[:, 2]**1)[:, None],
        (X2[:, 1]**1 * X2[:, 2]**2)[:, None],
        (X2[:, 1]**1 * X2[:, 2]**3)[:, None],
        (X2[:, 1]**1 * X2[:, 2]**4)[:, None],
        (X2[:, 1]**1 * X2[:, 2]**5)[:, None],
        (X2[:, 1]**2 * X2[:, 2]**1)[:, None],
        (X2[:, 1]**2 * X2[:, 2]**2)[:, None],
        (X2[:, 1]**2 * X2[:, 2]**3)[:, None],
        (X2[:, 1]**2 * X2[:, 2]**4)[:, None],
        (X2[:, 1]**3 * X2[:, 2]**1)[:, None],
        (X2[:, 1]**3 * X2[:, 2]**2)[:, None],
        (X2[:, 1]**3 * X2[:, 2]**3)[:, None],
        (X2[:, 1]**4 * X2[:, 2]**1)[:, None],
        (X2[:, 1]**4 * X2[:, 2]**2)[:, None],
        (X2[:, 1]**5 * X2[:, 2]**1)[:, None],
        (X2[:, 1]**2)[:, None],
        (X2[:, 1]**3)[:, None],
        (X2[:, 1]**4)[:, None],
        (X2[:, 1]**5)[:, None],
        (X2[:, 1]**6)[:, None],
        (X2[:, 2]**2)[:, None],
        (X2[:, 2]**3)[:, None],
        (X2[:, 2]**4)[:, None],
        (X2[:, 2]**5)[:, None],
        (X2[:, 2]**6)[:, None],
    ), axis=1)

X2_superpoly[:2]
# Out:
# array([[  1.00000000e+00,   5.12670000e-02,   6.99560000e-01,
#           3.58643425e-02,   2.50892595e-02,   1.75514423e-02,
#           1.22782870e-02,   8.58939846e-03,   1.83865725e-03,
#           1.28625106e-03,   8.99809795e-04,   6.29470940e-04,
#           9.42624411e-05,   6.59422333e-05,   4.61305487e-05,
#           4.83255257e-06,   3.38066048e-06,   2.47750473e-07,
#           2.62830529e-03,   1.34745327e-04,   6.90798869e-06,
#           3.54151856e-07,   1.81563032e-08,   4.89384194e-01,
#           3.42353606e-01,   2.39496889e-01,   1.67542444e-01,
#           1.17205992e-01],
#        [  1.00000000e+00,  -9.27420000e-02,   6.84940000e-01,
#          -6.35227055e-02,  -4.35092419e-02,  -2.98012201e-02,
#          -2.04120477e-02,  -1.39810280e-02,   5.89122275e-03,
#           4.03513411e-03,   2.76382476e-03,   1.89305413e-03,
#          -5.46363780e-04,  -3.74226408e-04,  -2.56322636e-04,
#           5.06708697e-05,   3.47065055e-05,  -4.69931780e-06,
# ...

# %%
theta2_superpoly = np.zeros(X2_superpoly.shape[1])
for x in range(1000000):
    theta2_superpoly = update_theta(X2_superpoly, y2, theta2_superpoly, alpha=0.1)
    
print(theta2_superpoly)

print(cost(X2_superpoly, y2, theta2_superpoly))
# Out:
# [  3.43049141   0.4858605    4.91512202  -9.33375283  11.91499398
#    0.4459137  -16.70906601 -13.77700153   7.8293116  -11.36959828
#   -9.45350003 -19.24386554   3.6110328   14.734565    13.59258531
#   -5.25956437  -2.42824178  -8.45762124  -5.26864201   5.55820717
#    1.77231311  -3.20195994 -17.94737168   0.54782398  -4.89273695
#  -21.10492366  12.09496915   0.84536209]
# 0.293803255632

# %% [markdown]
# ## With Regularization

# %%
# Sigmoid / Logistic Function
def g(x):
    return 1 / (1 + np.e ** (-x))

# Logistic Regression Hypothesis Function
def h(X, theta):
    return g(X.dot(theta))

# Logistic Regression Cost Function
def cost(X, y, theta):
    return (-1 / len(X)) * sum(y*np.log(h(X, theta)) + (1-y)*np.log(1-h(X, theta)))

import copy
def update_theta_with_reg(X, y, theta, alpha, lambda_reg):
    theta_for_reg = copy.deepcopy(theta)
    theta_for_reg[0] = 0
    return theta - (alpha / len(X)) * X.T.dot(h(X, theta) - y) - (lambda_reg / len(X)) * theta_for_reg

# %%
theta2_superpoly_with_reg = np.zeros(X2_superpoly.shape[1])
for x in range(1000000):
    theta2_superpoly_with_reg = update_theta_with_reg(X2_superpoly, y2, theta2_superpoly_with_reg, alpha=0.1, lambda_reg=1)
    
print(theta2_superpoly_with_reg)

print(cost(X2_superpoly, y2, theta2_superpoly_with_reg))
# Out:
# [ 0.32617789 -0.00815028  0.1657974  -0.11177305 -0.06509883 -0.02809802
#  -0.04163133 -0.01206586 -0.05789003 -0.11670694 -0.04886562 -0.06352867
#  -0.01297379 -0.02242245 -0.00052916 -0.03704601 -0.05796667 -0.00291261
#  -0.44671852 -0.07145281 -0.33672919 -0.1161486  -0.25333941 -0.2789162
#  -0.1063696  -0.28602599 -0.18675647 -0.27148704]
# 0.616394257746

# %%
theta2_superpoly_with_reg = np.zeros(X2_superpoly.shape[1])
for x in range(1000000):
    theta2_superpoly_with_reg = update_theta_with_reg(X2_superpoly, y2, theta2_superpoly_with_reg, alpha=0.1, lambda_reg=0.01)
    
print(theta2_superpoly_with_reg)

print(cost(X2_superpoly, y2, theta2_superpoly_with_reg))
# Out:
# [ 2.75388413  1.80721768  2.95666441 -3.37950877 -0.47234561 -1.20788379
#  -1.21215566 -0.9579347  -1.07820525 -1.76305303 -1.13701462 -1.14910685
#   0.52791718  0.62375084  0.42674109 -0.47032531 -0.73621911  0.44537441
#  -4.21449839  0.74552731 -3.26575302 -0.62159991 -2.63126635 -4.225343
#  -0.49913218 -2.77794836 -0.09178609 -1.14889867]
# 0.352376103629

# %%
thetas = []
for lambda_reg in [0.001, 0.01, 0.1, 1, 10]:
    theta2_superpoly_with_reg = np.zeros(X2_superpoly.shape[1])
    for x in range(100000):
        theta2_superpoly_with_reg = update_theta_with_reg(X2_superpoly, y2, theta2_superpoly_with_reg, alpha=0.1, lambda_reg=lambda_reg)
    thetas.append((lambda_reg, theta2_superpoly_with_reg))

for t in thetas:
    print('lambda_reg: {} -- cost: {}'.format(t[0], cost(X2_superpoly, y2, t[1])))
# Out:
# lambda_reg: 0.001 -- cost: 0.3198500946806681
# lambda_reg: 0.01 -- cost: 0.35237631954164383
# lambda_reg: 0.1 -- cost: 0.4624593959216265
# lambda_reg: 1 -- cost: 0.61639425774633
# lambda_reg: 10 -- cost: 0.6803808087867563
